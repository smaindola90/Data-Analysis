# %% [markdown]
# # Speedtest By Ookla - 2020Q1
#
# ### Analysis and Visualization of "Speedtest by Ookla" Data.
#
# The following data was provided by <a href="https://www.kaggle.com">Kaggle</a>

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# [Row(Name='Afghanistan', Number of Records='989', Devices='3,776', Tests='15,046', Avg. Avg U Kbps='3,984', Avg. Avg D Kbps='3,564', Avg Lat Ms='85', Avg. Pop2005='25,067,407', Rank Upload='193', Rank Download='226', Rank Latency='41'),
#  Row(Name='Åland Islands', Number of Records='252', Devices='485', Tests='1,068', Avg. Avg U Kbps='52,179', Avg. Avg D Kbps='64,138', Avg Lat Ms='12', Avg. Pop2005='0', Rank Upload='18', Rank Download='34', Rank Latency='223'),
#  Row(Name='Albania', Number of Records='8,275', Devices='45,779', Tests='174,707', Avg. Avg U Kbps='10,008', Avg. Avg D Kbps='13,911', Avg Lat Ms='29', Avg. Pop2005='3,153,731', Rank Upload='107', Rank Download='140', Rank Latency='155'),
#  Row(Name='Algeria', Number of Records='11,913', Devices='39,923', Tests='170,080', Avg. Avg U Kbps='1,368', Avg. Avg D Kbps='3,492', Avg Lat Ms='61', Avg. Pop2005='32,854,159', Rank Upload='230', Rank Download='227', Rank Latency='60'),
# ...
